# %%
#data structure 

#list are order,mutable(can change),mixed data
#LBigbracket

# %%
empty_list={]

# %%
type(empty_list)
    print(type)
# Out:
#   Cell In[2], line 2
#     print(type)
#     ^
# IndentationError: unexpected indent

# %%
#list of integer
#num=[1,2'3]
#mixed
#matrix
matrix=[[1,2],[3,4]]
print(type(matrix[0]))
matrix[0][1]
# Out:
# <class 'list'>
# 2

# %%
matrix=[[1,[3,5]],[4,5],[3,9]]
matrix[0][1][1]
matrix[0][1][1]="python"
matrix
# Out:
# [[1, [3, 'python']], [4, 5], [3, 9]]

# %%
matrix[1][0]-matrix[0][0]
# Out:
# 3

# %%
#tuple small braket
#list item can be changed but not tuple

matrix= [(1,5),(4,5),(3,4)]
matrix[2]
matrix[2]="python"
#print(type(matrix[1]))
matrix[1][0]="java"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       4 matrix= [(1,5),(4,5),(3,4)]
#       5 matrix[2]
#       6 matrix[2]="python"
#       7 #print(type(matrix[1]))
# ----> 8 matrix[1][0]="java"
#       9
#
# TypeError: 'tuple' object does not support item assignment

# %%
#append add at lst

# %%
dir(matrix)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
fruits=["apple","banana","orange"]
fruit=["cherry","gauva"]
fruits.append("applr")
fruits.extend(fruit)
fruits.insert(1,"kiwi")
pooped=fruits.pop()
print(pooped)
fruits
# Out:
# ['apple', 'kiwi', 'banana', 'orange', 'applr', 'cherry']

# %%
#slicing

numbers =[0,1,2,4,5]
subset=numbers[::2]#:start from zero :till end and step 2
print(subset)
# Out:
# (0, 2, 5)

# %%
#extract the value

matrix =

# %%
lis1=["ve",1,2,5,"ten"]
type(lis1)
lis1[2]
lis1[::2]
lis1[2::1]
print(lis1)
# Out:
# ['ve', 1, 2, 5, 'ten']

# %%
lis = ["nen",1,4,5,6,7,8]
lis[2:6:2]
# Out:
# [4, 6]

# %%
###append',
 #'clear',
 #'copy',
 #'count',
 #'extend',
 #'index',
 #'insert',
 #'pop',
 #'remove',
 #'reverse',
 #'sort']

# %%
place = ["ktm","ctwn","brgnj","dhn",]
place.count("ktm")
place.index("ctwn")
place.insert(2,"pokhara")
place.append("bharava")

plac1= ["brgnj","dharan","illam"]
place.extend(plac1)
pl
#place2

# %%
lis3 =["nen","ten","ten",23,4,5,6,"apple","java"]
lis3.append("pyhton")
lis3
lis3.remove("ten")
lis3
lis3.pop(3)
lis3.pop()
lis3.count("ten")
lis3.remove(23)
lis3.remove("java")
#print(lis3.index("ten"))
print(lis3.reverse())
print(lis3)
# Out:
# None
# ['apple', 6, 5, 'ten', 'nen']

# %%
number=[1,2,3,4,5]
#sqaure=[]
#for i in number:
   # sqaure.append(i**2)
#print(sqaure)

square = [i**2 for i in number]
print(square)
# Out:
# [1, 4, 9, 16, 25]

# %%
name1 = """What can Python do?
Python can be used on a server to create web applications.
Python can be used alongside software to create workflows.
Python can connect to database systems. It can also read and modify files.
Python can be used to handle big data and perform complex mathematics.
Python can be used for rapid prototyping, or for production-ready software development."""


print(name1.upper())
# Out:
# WHAT CAN PYTHON DO?
# PYTHON CAN BE USED ON A SERVER TO CREATE WEB APPLICATIONS.
# PYTHON CAN BE USED ALONGSIDE SOFTWARE TO CREATE WORKFLOWS.
# PYTHON CAN CONNECT TO DATABASE SYSTEMS. IT CAN ALSO READ AND MODIFY FILES.
# PYTHON CAN BE USED TO HANDLE BIG DATA AND PERFORM COMPLEX MATHEMATICS.
# PYTHON CAN BE USED FOR RAPID PROTOTYPING, OR FOR PRODUCTION-READY SOFTWARE DEVELOPMENT.

# %%
print(name1.lower())
# Out:
# what can python do?
# python can be used on a server to create web applications.
# python can be used alongside software to create workflows.
# python can connect to database systems. it can also read and modify files.
# python can be used to handle big data and perform complex mathematics.
# python can be used for rapid prototyping, or for production-ready software development.

# %%
print(name1.capitalize())
# Out:
# What can python do?
# python can be used on a server to create web applications.
# python can be used alongside software to create workflows.
# python can connect to database systems. it can also read and modify files.
# python can be used to handle big data and perform complex mathematics.
# python can be used for rapid prototyping, or for production-ready software development.

# %%
print(name1.lstrip())
# Out:
# What can Python do?
# Python can be used on a server to create web applications.
# Python can be used alongside software to create workflows.
# Python can connect to database systems. It can also read and modify files.
# Python can be used to handle big data and perform complex mathematics.
# Python can be used for rapid prototyping, or for production-ready software development.

# %%
print(name1.split(' '))
# Out:
# ['What', 'can', 'Python', 'do?\nPython', 'can', 'be', 'used', 'on', 'a', 'server', 'to', 'create', 'web', 'applications.\nPython', 'can', 'be', 'used', 'alongside', 'software', 'to', 'create', 'workflows.\nPython', 'can', 'connect', 'to', 'database', 'systems.', 'It', 'can', 'also', 'read', 'and', 'modify', 'files.\nPython', 'can', 'be', 'used', 'to', 'handle', 'big', 'data', 'and', 'perform', 'complex', 'mathematics.\nPython', 'can', 'be', 'used', 'for', 'rapid', 'prototyping,', 'or', 'for', 'production-ready', 'software', 'development.']

# %%
print(name1.replace("a","d"))
# Out:
# Whdt cdn Python do?
# Python cdn be used on d server to credte web dpplicdtions.
# Python cdn be used dlongside softwdre to credte workflows.
# Python cdn connect to ddtdbdse systems. It cdn dlso redd dnd modify files.
# Python cdn be used to hdndle big ddtd dnd perform complex mdthemdtics.
# Python cdn be used for rdpid prototyping, or for production-reddy softwdre development.

# %%
print(name1.count('a'))
# Out:
# 30

# %%
#give list print only even numbers
num = [12,13,14,65,7,8]
num1=[]
for i in num:
    if i%2==0:
        num1.append(i)
print(num1)
# Out:
# [12, 14, 8]

# %%
num1 = [1,2,3,-4,-5.-6]
count1=0
count2=0
for i in num1:
    if i>0:
        count1+=1
    else:
        count2+=1
print(count1)
print(count2)
# Out:
# 3
# 2

# %%
#search fruit
fruits=["apple","banana","kiwi"]
fruit=input("enter a fruit")
if fruit  in fruits:
    print("fruit found")
else:
    print("food not found")
# Out:
# enter a fruit mango
# food not found

# %%
#tuple

#order,immutable

empty_tuple=()
coordinate =(3,4)
mix_tuple=("hello",4,False)
mix_tuple[0]
# Out:
# 'hello'

# %%
point=(10,20,"10",10.0,"ten")
x,y=point
print(type(y))
print(dir(point))
print(point.count(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 point=(10,20,"10",10.0,"ten")
# ----> 2 x,y=point
#       3 print(type(y))
#       4 print(dir(point))
#       5 print(point.count(10))
#
# ValueError: too many values to unpack (expected 2, got 5)

# %%
point

# %%
#x = (1,2,3,2,2,2,2,2,5)
tup = ("1",3)*4
print(tup)
tup.count(1)
tup.index(5)
# Out:
# ('1', 3, '1', 3, '1', 3, '1', 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 5
#       1 #x = (1,2,3,2,2,2,2,2,5)
#       2 tup = ("1",3)*4
#       3 print(tup)
#       4 tup.count(1)
# ----> 5 tup.index(5)
#
# ValueError: tuple.index(x): x not in tuple

# %%
#list comprehension

number = [1,2,4,5,6]
square =[x**2 for x in number if x%2==0]
print(square)
# Out:
# [4, 16, 36]

# %%
num1 = [2,4,6,8]
num2=[]
for i in num1:
     if 
        num2.append(i)
print(num2)
# Out:
#   Cell In[39], line 4
#     i**2:
#         ^
# SyntaxError: invalid syntax

# %%
num1 = [2,4,6,8] #operation foroop condition
#num2 =[]
#for i in num1:
   # if i%2==0:
       # num2.append(i**2)
#print(num2)
num2 =[i**2 for i in num1 if i%2==0]
print(num2)
# Out:
# [4, 16, 36, 64]

# %%
words = ["apple", "kiwi", "banana"]

words = [word.capitalize() for word in words if "a" in words]

print(words)
# Out:
# []

# %%
s= "learning python programing"
vowels =  [char for char in s if char in "a

# %%
empty_dict={}
student={"name": "Alice",
         "age":21,
         "courses":["Maths","Physics"]

        }
print(student)
print(student["name"])
#unorder,valeue in diffrent data type,no dublicate key,value mutlaBE
# Out:
# {'name': 'Alice', 'age': 21, 'courses': ['Maths', 'Physics']}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
