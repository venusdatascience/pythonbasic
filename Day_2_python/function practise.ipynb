# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a,b=3,4
temp=3
a=b
b=temp
#a,b=b,a

# %%
x=y=z="bird"
print(f"

# %%
##**Today's Topics:**

##1.  **Functions:**
   ## *   What they are and why we use them.
    #*   Defining your own functions (`def`).
    #*   Passing information *into* functions (Parameters and Arguments).
   # *   Getting results *back* from functions (`return`).
#2.  **Variable Scope:**
    #*   Where variables exist (Local vs. Global).
    #*   How long variables exist (Lifetime).
#3.  **Lambda Functions:** A shortcut for creating simple, one-line functions.

# %%
def greet_person(a,b):
    print(f"Hello, {a} {b} ")

user_input = input("Enter the last name:")
greet_person(b=user_input,a="Harry")
# Out:
# Enter the last name: singh
# Hello, Harry singh

# %%
def add(x,y):
    print(f"addition of twonumbers: {x+y}")
    return x+y

add(3,4)
new_num=add(3,4)
# Out:
# addition of twonumbers: 7
# addition of twonumbers: 7

# %%
# 1. Define a simple function
def greet_user():
   
    print("Hello there, user!")
    print("Welcome to the world of functions.")

    return

# --- Code outside the function ---
print("Program starting...")
new_name=greet_user()
# Out:
# Program starting...
# Hello there, user!
# Welcome to the world of functions.

# %%
#exampldef add(a,b):
 def add(a,b):
    return a + b
   
x = int(input("Enter the first number:"))
y = int(input("Enter the second number:"))

result = add(x,y)
print(f"Result of {x} and {y}:  {result}")
# Out:
#   Cell In[9], line 2
#     def add(a,b):
#     ^
# IndentationError: unexpected indent

# %%
def sub(a,b):
    return a-b

x=int(input("eneter the first number"))
y=int(input("enter the second number"))

new_num=sub(x,y)
print(f"result of {x} and {y}: {new_num}")
# Out:
# eneter the first number 34
# enter the second number 12
# result of 34 and 12: 22

# %%
# *args and **kwargs
# Use *args to pass multiple positional arguments.


def show_args(*args):
   
    lists =""
    for item in args:
        print(item)
        lists += item
    return lists

value =show_args("111", "222")
print(value)
# Out:
# 111
# 222
# 111222

# %%
#example

def lis_arg(*ast):
    lists=""
    for i in ast:
        print(i)
        lists +=i
    return lists

new_value=lis_arg("aaa","2s2","vvv")
# Out:
# aaa
# 2s2
# vvv

# %%
#example

def lis1_arg(**asr):
    listf =""
    for i in asr:
        print(i)
        listf+=i
    return listf
new_name=lis1_arg(x="vin",y="sin",z="rin")
# Out:
# x
# y
# z

# %%
sum1 = 0
def addition(*args):
    for item in args:
        global sum1
        sum1 = sum1 + item
    return sum1

addition(1,2,4,22,44,55,55)
# Out:
# 183

# %%
#gobal variable
#sum=0
def add(*ad):
    sum=0
    for i in ad:
           sum+=i
    return sum

new_num1=add(1,2,3,4,5,6,7,8,34,52,34)
print(new_num1)

print(sum)
# Out:
# 156
# 0

# %%
#example
def Find_number(*ad):
    #lis1=0
    for i in ad:
        if i%2==0:
            print(f"the given number {i }is even:")
        else:
            print(f"the given number{i} is odd")
        #lis1+=i

    return i
new_val=Find_number(12,24,23,4,6,7,46)
# Out:
# the given number 12is even:
# the given number 24is even:
# the given number23 is odd
# the given number 4is even:
# the given number 6is even:
# the given number7 is odd
# the given number 46is even:

# %%
#exampleadd list of number

def lis1_num(*at):
    a1=0
    for i in at:
        a1+=i
    return a1

new_lis=lis1_num(1,2,3,4,5,6)
print(new_lis)
# Out:
# 21

# %%
#example

def num_vol(*arg):
    for i in arg:
        if i in('a','e','i','o','u'):
            print(f"{i} is vowel")
        else:
            print(f"{i} is consonent")
    return i

new1=num_vol("python", "is", "a","fun", "language")
# Out:
# python is consonent
# is is consonent
# a is vowel
# fun is consonent
# language is consonent

# %%
#lambda function

lambda x:x+10
print(x)
# Out:
# 34

# %%
double = lambda x,y: x * y
print(type(double))
print(double(5,6))

def double(x,y):
    return x*y

double(5,6)
# Out:
# <class 'function'>
# 30
# 30

# %%
double=lambda x,y,z:x*y*z
print(double(4,5,6))
# Out:
# 120

# %%
name_person=lambda x,y:x**2+y
print(name_person(2,3))
# Out:
# 7

# %%
#sorting

lis1=[(1,2),{3,4),(4,5)]
sorted_lis=sorted
# Out:
#   Cell In[49], line 3
#     lis1=[(1,2),{3,4),(4,5)]
#                     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '{'

# %%
list1=[1,7,9,4]
new_place=sorted(list1)
print(new_place)
# Out:
# [1, 4, 7, 9]

# %%
name_person=["ven","ren","ten"]
new_name=sorted(name_person,reverse=True)
print(new_name)
# Out:
# ['ven', 'ten', 'ren']

# %%
pairs=[(1,3),(2,4),(4,5),(1,6)]
new_value=sorted(pairs,key=lambda x:x[1])
print(new_value)
# Out:
# [(1, 3), (2, 4), (4, 5), (1, 6)]

# %%
#filter

nums = [1, 2, 3, 4, 5, 6]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)
# Out:
# [2, 4, 6]

# %%
num1=[12,14,16,18,20,17]
evn=list(filter(lambda x:x%3==0,num1))
print(evn)
# Out:
# [12, 18]

# %%
#map
numbers = [1, 2, 3, 4]
squared = list(map(lambda x: x ** 2, numbers))
print(squared)
# Out:
# [1, 4, 9, 16]

# %%
num2=[1.4,5,6]
sqr=list(map(lambda x:x*2,num2))
print(sqr)
# Out:
# [2.8, 10, 12]

# %%
help string
# Out:
#   Cell In[6], line 1
#     help string
#          ^
# SyntaxError: invalid syntax

# %%
dir string
# Out:
#   Cell In[7], line 1
#     dir string
#         ^
# SyntaxError: invalid syntax

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
text="python is intresting"
new_text=text.replace("is","are")
new1=text.upper()
print(new_text)
print(new1)
# Out:
# python are intresting
# PYTHON IS INTRESTING

# %%
text1="""If there is only one argument, it must be a dictionary mapping Unicode
 |      ordinals (integers) or characters to Unicode ordinals, strings or None.
 |      Character keys will be then converted to ordinals.
 |      If there are two arguments, they must be strings of equal length, and
 |      in the resulting dictionary, each character in x will be mapped to the
 |      character at the same position in y. If there is a third argument, it
 |    must be a string, whose characters will be mapped to None in the result."""
new2=text1.replace('a','b')
print(new2)
new3=text.split('-')
new4=text.strip
print(new3)
# Out:
# If there is only one brgument, it must be b dictionbry mbpping Unicode
#  |      ordinbls (integers) or chbrbcters to Unicode ordinbls, strings or None.
#  |      Chbrbcter keys will be then converted to ordinbls.
#  |      If there bre two brguments, they must be strings of equbl length, bnd
#  |      in the resulting dictionbry, ebch chbrbcter in x will be mbpped to the
#  |      chbrbcter bt the sbme position in y. If there is b third brgument, it
#  |    must be b string, whose chbrbcters will be mbpped to None in the result.
# ['python is intresting']
