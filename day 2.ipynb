# %%
count=0
print("count till 5:")
while count <5:
    print(f"count is:{count}")
    count +=1
print("loop finished.")
print(

# %%
#function

def name():
    print("i m learning pyhton")
name()
# Out:
# i m learning pyhton

# %%
#example 1

def add():
    a1=int(input("enter a number"))
    a2=int(input("enter a number"))
    print("addition of two number is:",a1+a2)

add()
12
12
# Out:
# enter a number 12
# enter a number 23
# addition of two number is: 35
# 12

# %%
#example 2

def

# %%
#add two number

def add(a,b):
    print(f"addition of two number is:{a+b}")

add(3,4)
# Out:
# addition of two number is:7

# %%
#square of two number

num=int(input("enter a number"))

def square_no(num):
    print(f"square of this number is:{num**2}")

square_no(num)
# Out:
# enter a number 5
# square of this number is:25

# %%
#Find largest among three numbers
#Check whether a number is even or odd
#Calculate simple interest

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
c=int(input("enter third number"))
print("check which number is greater among three")
      
if a>b and a>c:
    print(f"first number is greater: {a}")
elif b>a and b>c:
    print(f"second number is greater: {b}")
elif c>a and c>b:
    print(f"third numbe ris greater: {c}")
else:
    print("end")
# Out:
# enter first number 2
# enter second number 4
# enter third number 5
# check which number is greater among three
# third numbe ris greater: 5

# %%
#Check whether a number is even or odd

num1=int(input("enter one number:"))

if num%2==0:
    print(f"number  {num1} is even ")
else:
    print(f"number {num1} is odd")
# Out:
# enter one number: 34
# number 34 is odd

# %%
#Calculate simple interes

# %%
#function

def greet_person(a,b):
    print(f"hello,{a},{b}")

greet_person("jhon",3)
# Out:
# hello,jhon,3

# %%
def greet_person(a,b):
    print(f"hello,{a},{b}")


user_input=input("enter name")

greet_person(b=jhon",3)

# %%
def add_num(x,y,z=5):
    result = x+y+z
    print(f"the sum of {x}, {y} ,{z} is {result}")
    return result
final_ans=add_num(2,4)
print(final_ans)
# Out:
# the sum of 2, 4 ,5 is 11
# 11

# %%
double =lambda x,y :x*y
print(double(5,6))
# Out:
# 30

# %%
def double(x,y):
    print(f"multiplication z: {x*y}")

return
# Out:
#   Cell In[4], line 4
#     return
#     ^
# SyntaxError: 'return' outside function

# %%
def double(x, y):
    return x * y

result = double(5, 6)
print(result)
# Out:
# 30

# %%
def double(x, y):
    return x * y

result = double(5, 6)
print(result)

Output:

# %%
double=lambda x,y:x+y
print(double(5,6))
# Out:
# 11

# %%
pairs =[(1,3),(4,4),(2,1)]

sorted_pairs =sorted(pairs,key=lambda x:x[0])
print(f"sorted by second element:{sorted_pairs}")
# Out:
# sorted by second element:[(1, 3), (2, 1), (4, 4)]

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
number =[1,2,3]
sqaure=list(map(lambda x:x*2,number))
print(sqaure)
# Out:
# [2, 4, 6]

# %%
#operation in string

text="""he asked  him to helphhim"""
dir(text)
print(text.capitalize())
print(text.upper())
print(text.lower())
print(text.title())
# Out:
# He asked  him to helphhim
# HE ASKED  HIM TO HELPHHIM
# he asked  him to helphhim
# He Asked  Him To Helphhim

# %%
list_tuple=[(1,2),(3,4)]

final_text=''
for i,j in list_tuple:
    final_text=text.replace(i,j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       1 list_tuple=[(1,2),(3,4)]
#       2
#       3 final_text=''
#       4 for i,j in list_tuple:
# ----> 5     final_text=text.replace(i,j)
#
# TypeError: replace() argument 1 must be str, not int
